# %%
import pandas

# %%
dtxt = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.txt")

dtxt
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dtxt2 = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.txt", delimiter="|")

dtxt2
# Out:
#   ID,FirstName,LastName,Department,Phone,Address,Salary,Skills
# 0  1,Luke,Phillip,Sales,1234567890,"1st Address, ...
# 1  2,Jack,Darren,IT,1234567891,"2nd Address, Miam...
# 2  3,Ken,Wood,IT,1234567892,"3rd Address, Miami",...
# 3  4,John,Wilson,Marketing,1234567893,"4th Addres...
# 4  5,Emily,Larson,Marketing,1234567894,"5th Addre...
# 5  6,Anna,Sullivan,Sales,1234567895,"6th Address,...
# 6  7,Richard,Smith,Logistics,1234567896,"7th Addr...
# 7  8,Ronnie,Moore,Sales,1234567897,"8th Address, ...
# 8  9,Ron,Drake,IT,1234567898,"9th Address, Miami"...
# 9  10,Wayne,Barker,Logistics,1234567899,"10th Add...

# %%
dtxt2 = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.txt", sep = "|")

dtxt2
# Out:
#   ID,FirstName,LastName,Department,Phone,Address,Salary,Skills
# 0  1,Luke,Phillip,Sales,1234567890,"1st Address, ...
# 1  2,Jack,Darren,IT,1234567891,"2nd Address, Miam...
# 2  3,Ken,Wood,IT,1234567892,"3rd Address, Miami",...
# 3  4,John,Wilson,Marketing,1234567893,"4th Addres...
# 4  5,Emily,Larson,Marketing,1234567894,"5th Addre...
# 5  6,Anna,Sullivan,Sales,1234567895,"6th Address,...
# 6  7,Richard,Smith,Logistics,1234567896,"7th Addr...
# 7  8,Ronnie,Moore,Sales,1234567897,"8th Address, ...
# 8  9,Ron,Drake,IT,1234567898,"9th Address, Miami"...
# 9  10,Wayne,Barker,Logistics,1234567899,"10th Add...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv", header = None)
dcsv
# Out:
#      0          1         2           3           4                    5  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          6                7
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv", header = None, names = ["A","B","C","D","E","F","G","H"])
dcsv
# Out:
#      A          B         C           D           E                    F  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          G                H
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv", header = None, prefix = "COL")
dcsv
# Out:
#    COL0       COL1      COL2        COL3        COL4                 COL5  \
# 0    ID  FirstName  LastName  Department       Phone              Address
# 1     1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2     2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3     3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4     4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5     5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6     6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7     7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8     8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9     9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10   10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#       COL6             COL7
# 0   Salary           Skills
# ...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index("ID")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index("ID", inplace = True)
dcsv
# Out:
#    FirstName  LastName Department       Phone              Address  Salary  \
# ID
# 1       Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 2       Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 3        Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 4       John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5      Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 6       Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 7    Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 8     Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 9        Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#              Skills
# ID
# 1      Online Sales
# 2        Networking
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# ...

# %%
dcsv.set_index("Address", inplace = True)
dcsv
# Out:
#                     FirstName  LastName Department       Phone  Salary  \
# Address
# 1st Address, Miami       Luke   Phillip      Sales  1234567890   52000
# 2nd Address, Miami       Jack    Darren         IT  1234567891   52200
# 3rd Address, Miami        Ken      Wood         IT  1234567892   58000
# 4th Address, Miami       John    Wilson  Marketing  1234567893   58700
# 5th Address, Miami      Emily    Larson  Marketing  1234567894   60000
# 6th Address, Miami       Anna  Sullivan      Sales  1234567895   54000
# 7th Address, Miami    Richard     Smith  Logistics  1234567896   56000
# 8th Address, Miami     Ronnie     Moore      Sales  1234567897   49000
# 9th Address, Miami        Ron     Drake         IT  1234567898   53000
# 10th Address, Miami     Wayne    Barker  Logistics  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# 3rd Address, Miami      Python, Java
# ...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.shape
# Out:
# (10, 8)

# %%
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv", skiprows = 4)
dcsv
# Out:
#     4     John    Wilson  Marketing  1234567893   4th Address, Miami  58700  \
# 0   5    Emily    Larson  Marketing  1234567894   5th Address, Miami  60000
# 1   6     Anna  Sullivan      Sales  1234567895   6th Address, Miami  54000
# 2   7  Richard     Smith  Logistics  1234567896   7th Address, Miami  56000
# 3   8   Ronnie     Moore      Sales  1234567897   8th Address, Miami  49000
# 4   9      Ron     Drake         IT  1234567898   9th Address, Miami  53000
# 5  10    Wayne    Barker  Logistics  1234567899  10th Address, Miami  59500
#
#       Facebook Ads
# 0    Instagram Ads
# 1  In-Person Sales
# 2  Warehouse Mgmt.
# 3     Online Sales
# 4    Linux Servers
# 5  Product Loading

# %%
dcsv = pandas.read_csv(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.csv", nrows = 5)
dcsv
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 0   1      Luke  Phillip      Sales  1234567890  1st Address, Miami   52000
# 1   2      Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 2   3       Ken     Wood         IT  1234567892  3rd Address, Miami   58000
# 3   4      John   Wilson  Marketing  1234567893  4th Address, Miami   58700
# 4   5     Emily   Larson  Marketing  1234567894  5th Address, Miami   60000
#
#           Skills
# 0   Online Sales
# 1     Networking
# 2   Python, Java
# 3   Facebook Ads
# 4  Instagram Ads

# %%
djson = pandas.read_json(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.json")
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dxlsx = pandas.read_excel(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.xlsx")
dxlsx
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dxlsx = pandas.read_excel(r"C:\Udemy_Python_Masterclass\Data_Analysis_Automation\sample_data\Employees.xlsx", sheet_name = 0)
dxlsx
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...
