# %%
import pandas
import lxml

# %%
url = "https://pl.wikipedia.org/wiki/Python"

# %%
d = pandas.read_html(url)
d
# Out:
# [    0                                       1
#  0 NaN  Zobacz też: Python (zwierzęta), Pyton.,
#                                   0  \
#  0                           Python
#  1                           Python
#  2                      Logo języka
#  3                   Pojawienie się
#  4                       Paradygmat
#  5                        Typowanie
#  6                    Implementacje
#  7                         Pochodne
#  8         Aktualna wersja stabilna
#  9          Aktualna wersja testowa
#  10                          Twórca
#  11                        Licencja
#  12             Platforma sprzętowa
#  13             Platforma systemowa
#  14             Książki w Wikibooks
#  15                             NaN
#  16  Multimedia w Wikimedia Commons
#  17                             NaN
#  18              Strona internetowa
#
#                                                      1
#  0                                              Python
# ...

# %%
d = pandas.read_html(url)[1]
d
# Out:
#                                  0  \
# 0                           Python
# 1                           Python
# 2                      Logo języka
# 3                   Pojawienie się
# 4                       Paradygmat
# 5                        Typowanie
# 6                    Implementacje
# 7                         Pochodne
# 8         Aktualna wersja stabilna
# 9          Aktualna wersja testowa
# 10                          Twórca
# 11                        Licencja
# 12             Platforma sprzętowa
# 13             Platforma systemowa
# 14             Książki w Wikibooks
# 15                             NaN
# 16  Multimedia w Wikimedia Commons
# 17                             NaN
# 18              Strona internetowa
#
#                                                     1
# 0                                              Python
# 1                                                 NaN
# 2                                         Logo języka
# ...
